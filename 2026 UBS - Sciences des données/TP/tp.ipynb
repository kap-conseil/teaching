# %% [markdown]
# # Travaux pratiques - mise en oeuvre de méthodes de prévisions pour les séries temporelles avec algorithmes de gradient boosting

# %%
## Logique du TP

Ces travaux vous proposent de mettre en oeuvre des techniques de prévision par régression sur de ses valeurs passées et de faceteurs exogènes. Nous allons utiliser des algorithmes de gradient boosting, qui sont des méthodes d'ensemble basées sur la construction séquentielle de modèles faibles (comme les arbres de décision) pour améliorer les performances de prédiction.

L'objectif 
Des sections de code vous sont fournies pour préparer les données requises et vous guider à certains points clés. Il est nécessaire de les exécuter.
Vos développements de codes sont à placer entre ces sections guides.

Un corrigé complet reprenant les numéros de sections de l'énoncé vous est donnée à la fin. 
Au préalable, vous devez installer les bibliothèques nécessaires listées dans le fichier `requirements.txt`.

# %% [markdown]
# ### 1. Objectif
#
# La préparation des données vous fournira une série temproelle de consommation d'un ménage au sud de Paris allant de XXX à XXX. De la météo prévisionnelles sera insérée dans les données. Votre objectif est de construire un modèle de prévision de la consommation à l'aide d'algorithmes de gradient boosting, en utilisant les données historiques et les facteurs exogènes (météo).
#
# Les étapes suivantes vous guideront à travers :
# * de préparation de l'échantillon d'apprentissage,
# * de construction du modèle,
# * apprentissage du modèle et choix des hyperparamètres,
# * d'évaluation des performances et comparaison à un benchmark simple,

# %% [markdown]
# ## Préparation de l'échantillon d'apprentissage
#
# La données de consommations électriques et de météo prévisionnelle (y compris de prévisions dans le passé) sont disponibles dans le fichier `data.csv`. Vous pouvez charger ces données à l'aide de la bibliothèque `pandas`.

# %% [markdown]
# ## Eléments de corrigé
